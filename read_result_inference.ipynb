# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/att_by_cohort_all_post.csv"
df = pd.read_csv("/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/att_by_cohort_all_post.csv")
display(df)
# Out:
# StatementMeta(, 6b4731e3-d260-459c-a7f6-3d0d7d8eb086, 22, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, a31f6efc-ded7-445c-b610-abd6255ead00)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/att_overall.csv"
df = pd.read_csv("/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/att_overall.csv")
display(df)
# Out:
# StatementMeta(, 6b4731e3-d260-459c-a7f6-3d0d7d8eb086, 24, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, f79ade0a-3b48-420e-a7a0-421a4f680101)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/att_overall_all_post.csv"
df = pd.read_csv("/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/att_overall_all_post.csv")
display(df)
# Out:
# StatementMeta(, 6b4731e3-d260-459c-a7f6-3d0d7d8eb086, 25, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, da112b2e-6d22-4050-ad04-5b83e7f7d5cf)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/att_overall_first_3m.csv"
df = pd.read_csv("/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/att_overall_first_3m.csv")
display(df)
# Out:
# StatementMeta(, 6b4731e3-d260-459c-a7f6-3d0d7d8eb086, 26, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, fee4614b-2af1-4b60-b175-f578579c24cb)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/cohort_dynamic.csv"
df = pd.read_csv("/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/cohort_dynamic.csv")
display(df)
# Out:
# StatementMeta(, 6b4731e3-d260-459c-a7f6-3d0d7d8eb086, 27, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 18f4c890-3e97-42a3-9049-5017dc16d8d1)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/overall_dynamic.csv"
df = pd.read_csv("/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/overall_dynamic.csv")
display(df)
# Out:
# StatementMeta(, 6b4731e3-d260-459c-a7f6-3d0d7d8eb086, 28, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 32cb1254-5826-4db6-b36e-c0fe2b59d53b)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/pretrend_test.csv"
df = pd.read_csv("/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/pretrend_test.csv")
display(df)
# Out:
# StatementMeta(, 6b4731e3-d260-459c-a7f6-3d0d7d8eb086, 29, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 6e8151d4-3367-40db-96ef-d21ea996921c)
