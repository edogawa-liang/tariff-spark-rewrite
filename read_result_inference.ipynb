# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/att_by_cohort_all_post.csv"
df = pd.read_csv("/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/att_by_cohort_all_post.csv")
display(df)
# Out:
# StatementMeta(, c7623c6c-eaf5-4ca1-ac40-5060a03ecea4, 11, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, d82f63ef-2b4d-4d89-85c4-c704a777de21)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/att_overall_all_post.csv"
df = pd.read_csv("/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/att_overall_all_post.csv")
display(df)
# Out:
# StatementMeta(, c7623c6c-eaf5-4ca1-ac40-5060a03ecea4, 12, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, b4dc202f-94a8-4407-86f9-5d12d1a74082)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/group_dynamic.csv"
df = pd.read_csv("/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/group_dynamic.csv")
display(df)
# Out:
# StatementMeta(, c7623c6c-eaf5-4ca1-ac40-5060a03ecea4, 13, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, a924f525-a971-44a5-b675-e598e8ed51b3)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/att_overall_first_3m.csv"
df = pd.read_csv("/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/att_overall_first_3m.csv")
display(df)
# Out:
# StatementMeta(, c7623c6c-eaf5-4ca1-ac40-5060a03ecea4, 14, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 7a95606a-d48e-41d6-8959-5de7733fdeb7)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/cohort_dynamic.csv"
df = pd.read_csv("/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/cohort_dynamic.csv")
display(df)
# Out:
# StatementMeta(, c7623c6c-eaf5-4ca1-ac40-5060a03ecea4, 15, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 83b910ef-6c61-4373-86ca-22e859614cda)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/overall_dynamic.csv"
df = pd.read_csv("/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/overall_dynamic.csv")
display(df)
# Out:
# StatementMeta(, c7623c6c-eaf5-4ca1-ac40-5060a03ecea4, 16, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, aa3e2cac-d61a-44b1-81cd-43b844e0241e)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/pretrend_test.csv"
df = pd.read_csv("/lakehouse/default/Files/output/inference/matching_high/calendar2_1year_high/pretrend_test.csv")
display(df)
# Out:
# StatementMeta(, c7623c6c-eaf5-4ca1-ac40-5060a03ecea4, 17, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 0756f501-e560-471f-95ec-9edca9675426)
